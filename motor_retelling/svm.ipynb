# %%
import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.svm import SVC
from scipy.stats import expon
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_curve, auc, recall_score, precision_score

def specificity_score(y_true, y_pred):
    """Calculate specificity (true negative rate)"""
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return tn / (tn + fp)

def train_randomized_inner_model(X_train, y_train, inner_folds, random_state, n_iter=1000):
    """Train model with inner CV grid search"""
    
    scaler=StandardScaler()
    X_train=scaler.fit_transform(X_train)
    
    # kernel lineal
    param_grid = {
        'C': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
        'gamma': [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
        'kernel': ['rbf']
    }
    
    svc1=SVC(random_state=random_state)
    grid_search = GridSearchCV(
        svc1,
        param_grid,
        cv=inner_folds,
        scoring='accuracy',
        n_jobs=-1,
        verbose=1
    )
    grid_search.fit(X_train, y_train)

    best_C = grid_search.best_params_['C']
    best_gamma = grid_search.best_params_['gamma']

    print("Initial best C from GridSearch:", best_C)
    print("Initial best gamma from GridSearch:", best_gamma)

    param_distributions = {
        'C': expon(scale=best_C),
        'gamma': expon(scale=best_gamma),
        'kernel': ['rbf']
    }
    
    svc=SVC(random_state=random_state)
    random_search = RandomizedSearchCV(
        svc,
        param_distributions=param_distributions,
        n_iter=n_iter,
        cv=inner_folds,
        scoring='accuracy',
        n_jobs=-1,
        verbose=1,
        random_state=random_state
    )

    random_search.fit(X_train, y_train)
    
    print("Final best params from RandomizedSearch:")
    print(random_search.best_params_)
    print("Final best score:", random_search.best_score_)

    return random_search

def plot_ROC_curve(all_y_true, all_y_proba, filename='roc_curve.png'):
    """Generate and save ROC curve"""

    fpr, tpr, _ = roc_curve(all_y_true, all_y_proba)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.savefig(filename)
    plt.close()

def plot_confusion_matrix(y_true, y_pred, filename='confusion_matrix.png'):

    cf_matrix = confusion_matrix(y_true, y_pred, normalize=("true"))
    cf_matrix_v = confusion_matrix(y_true, y_pred)
    
    # Define a color map for the heatmap
    cmap = sns.color_palette("Blues", as_cmap=True)
    
    plt.figure(figsize = (6,6))
    heatmap = sns.heatmap(cf_matrix, annot=False, cmap=cmap, fmt='d', xticklabels=['HC', 'PD'], yticklabels=['HC', 'PD'], square=True, cbar=True)
    # heatmap = sns.heatmap(data, annot=False, fmt='d', cmap=cmap)
    
    # Calculate and display percentages
    for i in range(len(cf_matrix)):
        for j in range(len(cf_matrix[i])):
            text = f"{cf_matrix[i][j]*100: 0.2f}% ({cf_matrix_v[i][j]})"
            
            # Calculate the background color at the center of the cell
            cell_bg_color = np.mean(cmap(cf_matrix[i][j]))
            print(i,j, cell_bg_color)
            # Choose a text color based on the background color
            text_color = 'black' if cell_bg_color > 0.7 else 'white'
                    
            heatmap.text(j + 0.5, i + 0.5, text, ha='center', va='center', color=text_color)

    plt.xlabel("Predicted")
    plt.ylabel("Real")
    plt.title("Confusion Matrix")
    plt.tight_layout()

    plt.savefig(filename, dpi=300)

    
    return cf_matrix

def plot_probability_density(y_true, y_proba, filename='probability_density.png'):
    """
    Plot density distribution of predicted probabilities for each class
    
    Parameters:
    -----------
    y_true : array-like
        True labels (0=HC, 1=PD)
    y_proba : array-like
        Predicted probabilities for class 1 (PD)
    save_path : str
        Path to save the plot
    """
    # Create DataFrame for plotting
    df = pd.DataFrame({
        'Probability': y_proba,
        'Group': ['HC' if label == 0 else 'PD' for label in y_true]
    })
    
    # Define colors (Soft blue shades)
    blues = sns.color_palette("Blues", n_colors=6)
    colors = [blues[1], blues[4]]  # light blue for HC, dark blue for PD

    # Create figure with two subplots: Boxplot (top) and Density plot (bottom)
    fig, axes = plt.subplots(nrows=2, ncols=1, gridspec_kw={'height_ratios': [1, 4]}, figsize=(6, 6), sharex=True)

    # Boxplot (Top)
    sns.boxplot(x="Probability", y="Group", data=df, dodge=False, palette=colors, ax=axes[0])
    axes[0].set_xlabel("")
    axes[0].set_ylabel("")
    axes[0].set_yticks([])
    axes[0].set_title("Predicted Probability Distribution")

    sns.histplot(data=df, x="Probability", hue="Group", kde=True, palette=colors, stat="density", bins=20, ax=axes[1], legend=True)
    
    axes[1].set_xlabel("Predicted Probability")
    legend_handles = [
        Patch(color=colors[0], label='HC'),
        Patch(color=colors[1], label='PD')
    ]
    axes[1].legend(handles=legend_handles)
    
    plt.tight_layout()
    plt.savefig(filename, dpi=300)
    plt.close()

def run_nested_svm_cv(fold_dict, features_df, random_state=42, type='_MOTOR_LIBRE.wav'):
    """
        Perform nested CV SVM classification with predefined folds
        
        Parameters:
        -----------
        fold_dict : dict
            Output from generate_nested_cv_folds()
        features_df : pd.DataFrame
            DataFrame with features (index=filename, columns=features)
        random_state : int
            Random seed for reproducibility
            
        Returns:
        --------
        tuple: (results_df, all_y_true, all_y_pred, all_y_proba)
    """

    C = []
    gamma = []
    results = []
    best_scores = []
    test_predictions = []
    all_scores = []

    for outer_fold, fold_info in fold_dict.items():
        test_ids = [id_ + type for id_ in fold_info["test"].keys()]
        y_test = list(fold_info["test"].values())

        train_labels_dict = {}
        for inner in fold_info["inner"].values():
            train_labels_dict.update(inner["train"])
            train_labels_dict.update(inner["val"])
        train_ids = [id_ + type for id_ in train_labels_dict.keys()]
        y_train = list(train_labels_dict.values())

        print(train_ids)
        X_train = features_df.loc[train_ids].values
        X_test = features_df.loc[test_ids].values

        inner_folds = []
        for inner_num, inner in fold_info["inner"].items():
            inner_train_ids = [id_ + type for id_ in inner["train"].keys()]
            val_ids = [id_ + type for id_ in inner["val"].keys()]
            train_idx = [i for i, id_ in enumerate(train_ids) if id_ in inner_train_ids]
            val_idx = [i for i, id_ in enumerate(train_ids) if id_ in val_ids]
            inner_folds.append((train_idx, val_idx))

        model = train_randomized_inner_model(X_train, y_train, inner_folds, random_state)

        print("--------------- Best Params ------------------")
        print(model.best_params_)
        print(model.best_score_)
        C.append(model.best_params_['C'])
        gamma.append(model.best_params_['gamma'])
        best_scores.append(model.best_score_)
    
    print(C, gamma)
    Copt=np.median(C)
    gammaopt=np.median(gamma)
    print(Copt, gammaopt)
    print('-----------------------------------------')
    print()

    for idx, (outer_fold, fold_info) in enumerate(fold_dict.items()):
        test_ids = [id_ + type for id_ in fold_info["test"].keys()]
        y_test = list(fold_info["test"].values())

        train_labels_dict = {}
        for inner in fold_info["inner"].values():
            train_labels_dict.update(inner["train"])
            train_labels_dict.update(inner["val"])
        train_ids = [id_ + type for id_ in train_labels_dict.keys()]
        y_train = list(train_labels_dict.values())

        X_train = features_df.loc[train_ids].values
        X_test = features_df.loc[test_ids].values

        scaler=StandardScaler()
        X_train=scaler.fit_transform(X_train)
        X_test=scaler.transform(X_test)

        model = SVC(C=Copt, gamma=gammaopt, kernel="rbf", random_state=random_state, probability=True)
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:, 1]

        train_decision_scores = model.decision_function(X_train)
        test_decision_scores = model.decision_function(X_test)

        for id_, score in zip(train_ids, train_decision_scores):
            all_scores.append({
                'id': id_,
                'score': score,
                'outer_fold': outer_fold,
                'set_type': 'train'
            })

        for id_, score in zip(test_ids, test_decision_scores):
            all_scores.append({
                'id': id_,
                'score': score,
                'outer_fold': outer_fold,
                'set_type': 'test'
            })

        acc = accuracy_score(y_test, y_pred)
        sens = recall_score(y_test, y_pred)
        spec = specificity_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        cm = confusion_matrix(y_test, y_pred)

        results.append({
            'outer_fold': outer_fold,
            'accuracy': acc,
            'sensitivity': sens,
            'specificity': spec,
            'f1': f1,
            'precision': prec,
            'confusion_matrix': cm,
            'C': C[idx],
            'gamma': gamma[idx]
        })

        for sample_id, yt, yp, yp_prob, sc in zip(test_ids, y_test, y_pred, y_proba, test_decision_scores):
            test_predictions.append({
                'id': sample_id,
                'y_true': yt,
                'y_pred': yp,
                'y_proba': yp_prob,
                'score': sc,
                'outer_fold': outer_fold
            })

        print(f"\nFold {outer_fold} Results:")
        print(f"Train set size: {len(y_train)}")
        print(f"Test set size: {len(y_test)}")
        print(f"Accuracy: {acc:.3f}")
        print(f"Sensitivity: {sens:.3f}")
        print(f"Specificity: {spec:.3f}")

    return results, test_predictions, all_scores

def run_late_fusion(fold_dict, scores_df, random_state=42, type='_MOTOR_LIBRE.wav'):
    """
    Perform late fusion using pre-merged scores from multiple modalities
    
    Parameters:
    -----------
    fold_dict : dict
        Dictionary containing the nested CV fold information
    scores_df : pd.DataFrame
        DataFrame containing merged scores from all modalities with columns:
        ['id', 'outer_fold', 'set_type', 'artic_score', 'phon_score', 'pros_score', ...]
    random_state : int
        Random seed for reproducibility
    type : str
        Suffix to add to IDs
        
    Returns:
    --------
    tuple: (results, test_predictions, inner_val_predictions)
    """
    C, best_scores = [], []
    results, test_predictions = [], []
    all_scores = []

    # Get the score columns (all columns that end with '_score')
    score_columns = [col for col in scores_df.columns if col.endswith('_score')]
    
    for outer_fold, fold_info in fold_dict.items():
        outer_fold = int(outer_fold)
        test_ids = [id_ + type for id_ in fold_info["test"].keys()]
        y_test = list(fold_info["test"].values())

        # Get training IDs and labels
        train_labels_dict = {}
        for inner in fold_info["inner"].values():
            train_labels_dict.update(inner["train"])
            train_labels_dict.update(inner["val"])
        train_ids = [id_ + type for id_ in train_labels_dict.keys()]
        y_train = list(train_labels_dict.values())
        
        # Get training and test data from scores_df
        X_train = scores_df[(scores_df['id'].isin(train_ids)) & 
                           (scores_df['outer_fold'] == outer_fold) &
                           (scores_df['set_type'] == 'train')][score_columns].values
        
        X_test = scores_df[(scores_df['id'].isin(test_ids)) & 
                          (scores_df['outer_fold'] == outer_fold) &
                          (scores_df['set_type'] == 'test')][score_columns].values

        # Create inner folds for hyperparameter tuning
        inner_folds = []
        for inner in fold_info["inner"].values():
            inner_train_ids = [id_ + type for id_ in inner["train"].keys()]
            val_ids = [id_ + type for id_ in inner["val"].keys()]
            train_idx = [i for i, id_ in enumerate(train_ids) if id_ in inner_train_ids]
            val_idx = [i for i, id_ in enumerate(train_ids) if id_ in val_ids]
            inner_folds.append((train_idx, val_idx))

        model = train_randomized_inner_model(X_train, y_train, inner_folds, random_state)

        print("--------------- Best Params ------------------")
        print(model.best_params_)
        print(model.best_score_)
        C.append(model.best_params_['C'])
        best_scores.append(model.best_score_)

    # Use median of best parameters from all outer folds
    Copt = np.median(C)
    print(f"Final SVM Params - C: {Copt}")
    print('-----------------------------------------\n')

    for idx, (outer_fold, fold_info) in enumerate(fold_dict.items()):
        outer_fold = int(outer_fold)
        test_ids = [id_ + type for id_ in fold_info["test"].keys()]
        y_test = list(fold_info["test"].values())

        train_labels_dict = {}
        for inner in fold_info["inner"].values():
            train_labels_dict.update(inner["train"])
            train_labels_dict.update(inner["val"])
        train_ids = [id_ + type for id_ in train_labels_dict.keys()]
        y_train = list(train_labels_dict.values())

        # Get data for final evaluation
        X_train = scores_df[(scores_df['id'].isin(train_ids)) & 
                          (scores_df['outer_fold'] == outer_fold) &
                          (scores_df['set_type'] == 'train')][score_columns].values
        
        X_test = scores_df[(scores_df['id'].isin(test_ids)) & 
                         (scores_df['outer_fold'] == outer_fold) &
                         (scores_df['set_type'] == 'test')][score_columns].values
        
        # Scale features
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        model = SVC(C=Copt, kernel="linear", random_state=random_state, probability=True)
        model.fit(X_train_scaled, y_train)

        y_pred = model.predict(X_test_scaled)
        y_proba = model.predict_proba(X_test_scaled)[:, 1]

        train_decision_scores = model.decision_function(X_train)
        test_decision_scores = model.decision_function(X_test)

        for id_, score in zip(train_ids, train_decision_scores):
            all_scores.append({
                'id': id_,
                'score': score,
                'outer_fold': outer_fold,
                'set_type': 'train'
            })

        for id_, score in zip(test_ids, test_decision_scores):
            all_scores.append({
                'id': id_,
                'score': score,
                'outer_fold': outer_fold,
                'set_type': 'test'
            })

        # Calculate metrics
        acc = accuracy_score(y_test, y_pred)
        sens = recall_score(y_test, y_pred)
        spec = specificity_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        cm = confusion_matrix(y_test, y_pred)

        results.append({
            'outer_fold': outer_fold,
            'accuracy': acc,
            'sensitivity': sens,
            'specificity': spec,
            'f1': f1,
            'precision': prec,
            'confusion_matrix': cm,
            'C': C[idx],
        })

        for sample_id, yt, yp, yp_prob, sc in zip(test_ids, y_test, y_pred, y_proba, test_decision_scores):
            test_predictions.append({
                'id': sample_id,
                'y_true': yt,
                'y_pred': yp,
                'y_proba': yp_prob,
                'score': sc,
                'outer_fold': outer_fold
            })

        print(f"\nFold {outer_fold} Results:")
        print(f"Train set size: {len(y_train)}")
        print(f"Test set size: {len(y_test)}")
        print(f"Accuracy: {acc:.3f}")
        print(f"Sensitivity: {sens:.3f}")
        print(f"Specificity: {spec:.3f}")

    return results, test_predictions, all_scores

# Load all folds
folds_paths = {
    "PD_vs_HC": "folds/PD_vs_HC_folds.json",
    "CTR_DCL_vs_Park_DCL": "folds/CTR_DCL_vs_Park_DCL_folds.json",
    "CTR_noDCL_vs_Park_noDCL": "folds/CTR_noDCL_vs_Park_noDCL_folds.json",
    "Park_noDCL_vs_Park_DCL": "folds/Park_noDCL_vs_Park_DCL_folds.json",
}

folds_data = {}
for name, path in folds_paths.items():
    with open(path, "r") as f:
        folds_data[name] = json.load(f)

# Load feature sets
features_dict = {
    "articulation": pd.read_csv('features_motor_libre/articulationfeatures_ML.csv').set_index('id'),
    "prosody": pd.read_csv('features_motor_libre/prosodyfeatures_ML.csv').set_index('id'),
    "phonological": pd.read_csv('features_motor_libre/phonologicalfeatures_ML.csv').set_index('id')
}

# %% [markdown]
# # Motor libre

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Running experiments for: {fold_name}")
    
    # Create directory for this fold if it doesn't exist
    os.makedirs(f"results_motor_libre/{fold_name}", exist_ok=True)

    for feat_type, feat_df in features_dict.items():
        print(f" - Feature set: {feat_type}")
        
        results, test_predictions, scores = run_nested_svm_cv(fold_data, feat_df)

        results_df = pd.DataFrame(results)
        test_predictions_df = pd.DataFrame(test_predictions)
        scored_df = pd.DataFrame(scores)

        # Save results
        results_df.to_csv(f"results_motor_libre/{fold_name}/{feat_type}_results.csv", index=False)
        test_predictions_df.to_csv(f"results_motor_libre/{fold_name}/{feat_type}_test_predictions.csv", index=False)
        scored_df.to_csv(f"results_motor_libre/{fold_name}/{feat_type}_scores.csv", index=False)

        all_y_true = [x['y_true'] for x in test_predictions]
        all_y_proba = [x['y_proba'] for x in test_predictions]
        all_y_pred = [x['y_pred'] for x in test_predictions]

        os.makedirs(f"results_motor_libre/{fold_name}/plots/", exist_ok=True)

        plot_ROC_curve(all_y_true, all_y_proba, f'results_motor_libre/{fold_name}/plots/roc_curve_{feat_type}.png')
        plot_confusion_matrix(all_y_true, all_y_pred, f'results_motor_libre/{fold_name}/plots/confusion_matrix_{feat_type}.png')
        plot_probability_density(all_y_true, all_y_proba, f'results_motor_libre/{fold_name}/plots/probability_density_{feat_type}.png')
# Out:
# Running experiments for: PD_vs_HC
#  - Feature set: articulation
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C004_MLQ_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C010_MVQG_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C012_CTRE_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTO
ODG_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C016_EALE_MOTOR_LIBRE.wav', 'C021_GDGR_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C035_JRPA_MOTOR_LIBRE.wav', 'C047_ISV_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.034993721443479085, 'gamma': 0.002400422887393024, 'kernel': 'rbf'}
# Final best score: 0.796875
# --------------- Best Params ------------------
# {'C': 0.034993721443479085, 'gamma': 0.002400422887393024, 'kernel': 'rbf'}
# 0.796875
# [218.22519124015147, 0.2838271575399164, 0.826214260143961, 7.473978139587696, 0.034993721443479085] [6.390661333763098e-05, 0.0017381148651515006, 0.003161203427295335, 0.0013152378349869207, 0.002400422887393024]
# 0.826214260143961 0.0017381148651515006
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.875
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.750
# Specificity: 0.625
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.625
# Sensitivity: 0.375
# Specificity: 0.875
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.875
# Sensitivity: 0.875
# Specificity: 0.875
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.667
# Sensitivity: 0.750
# Specificity: 0.571
# 0 0 0.6069665513264129
# 0 1 0.8620184544405998
# 1 0 0.8794886582083814
# 1 1 0.5865436370626682
#  - Feature set: prosody
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C004_MLQ_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C010_MVQG_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C012_CTRE_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C015_HJOL_MOTOR_LIBRE.wav', 'C016_EALE_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C021_GDGR_MOTOR_LIBRE.wav', 'C026_JEPM_MOTOR_LIBRE.wav', 'C031_RALR_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav
R_LIBRE.wav', 'C035_JRPA_MOTOR_LIBRE.wav', 'C047_ISV_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1e-05
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.1527507630986618e-05, 'gamma': 0.005800908425853984, 'kernel': 'rbf'}
# Final best score: 0.734375
# --------------- Best Params ------------------
# {'C': 1.1527507630986618e-05, 'gamma': 0.005800908425853984, 'kernel': 'rbf'}
# 0.734375
# [0.5992390010381585, 19.885295716582227, 1.1978638819127894, 2.994577768406861, 1.1527507630986618e-05] [0.005271931976736665, 9.763011917123741e-05, 0.0007680784344120899, 0.010862557985649803, 0.005800908425853984]
# 1.1978638819127894 0.005271931976736665
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.562
# Sensitivity: 0.625
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.625
# Sensitivity: 0.375
# Specificity: 0.875
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.625
# Sensitivity: 0.500
# Specificity: 0.750
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.750
# Specificity: 0.625
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.600
# Sensitivity: 0.500
# Specificity: 0.714
# 0 0 0.6069665513264129
# 0 1 0.8620184544405998
# 1 0 0.7698961937716263
# 1 1 0.7026143790849673
#  - Feature set: phonological
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C004_MLQ_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C010_MVQG_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C012_CTRE_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C015_HJOL_MOTOR_LIBRE.wav', 'C016_EALE_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C021_GDGR_MOTOR_LIBRE.wav', 'C026_JEPM_MOTOR_LIBRE.wav', 'C031_RALR_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C040_NELC_MOTOR_LIBRE.wav', 'C042_MHL_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'C047_ISV_MOTOR_LIBRE.wav', 'C049_MLLR_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.
wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 124.94918749560257, 'gamma': 0.00022557667543306135, 'kernel': 'rbf'}
# Final best score: 0.859375
# --------------- Best Params ------------------
# {'C': 124.94918749560257, 'gamma': 0.00022557667543306135, 'kernel': 'rbf'}
# 0.859375
# [0.458522799264304, 0.5520331253049737, 25.935994568670672, 4.519744989669624, 124.94918749560257] [0.0010005037477317713, 0.023682376754780906, 0.0005608631232047705, 0.0035677981382916998, 0.00022557667543306135]
# 4.519744989669624 0.0010005037477317713
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.562
# Sensitivity: 0.875
# Specificity: 0.250
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.625
# Specificity: 0.875
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.375
# Specificity: 1.000
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.812
# Sensitivity: 0.625
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.600
# Sensitivity: 0.625
# Specificity: 0.571
# 0 0 0.5737793156478278
# 0 1 0.8904075355632449
# 1 0 0.8224913494809689
# 1 1 0.6503652441368705
# Running experiments for: CTR_DCL_vs_Park_DCL
#  - Feature set: articulation
# ['C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.9583333333333334
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.003010121430917521, 'kernel': 'rbf'}
# 0.9583333333333334
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'C003_EMAO_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 16.962487046234628, 'gamma': 1.6959629191460517e-05, 'kernel': 'rbf'}
# Final best score: 0.761904761904762
# --------------- Best Params ------------------
# {'C': 16.962487046234628, 'gamma': 1.6959629191460517e-05, 'kernel': 'rbf'}
# 0.761904761904762
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C003_EMAO_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.627537294604771, 'gamma': 7.439278308608545e-05, 'kernel': 'rbf'}
# Final best score: 0.886904761904762
# --------------- Best Params ------------------
# {'C': 3.627537294604771, 'gamma': 7.439278308608545e-05, 'kernel': 'rbf'}
# 0.886904761904762
# ['C003_EMAO_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C001R_AJZP_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.6726393087930425, 'gamma': 0.0029736877935069308, 'kernel': 'rbf'}
# Final best score: 0.8452380952380952
# --------------- Best Params ------------------
# {'C': 0.6726393087930425, 'gamma': 0.0029736877935069308, 'kernel': 'rbf'}
# 0.8452380952380952
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C003_EMAO_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 13.167456935454494, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.880952380952381
# --------------- Best Params ------------------
# {'C': 13.167456935454494, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.880952380952381
# [0.4692680899768591, 16.962487046234628, 3.627537294604771, 0.6726393087930425, 13.167456935454494] [0.003010121430917521, 1.6959629191460517e-05, 7.439278308608545e-05, 0.0029736877935069308, 0.0009129425537759533]
# 3.627537294604771 0.0009129425537759533
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.571
# Sensitivity: 0.667
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 0.750
# Specificity: 0.667
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
# 0 0 0.5686966551326413
# 0 1 0.8925913110342176
# 1 0 0.8925913110342176
# 1 1 0.5686966551326413
#  - Feature set: prosody
# ['C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 11.742125275677191, 'gamma': 0.0004889587009811018, 'kernel': 'rbf'}
# Final best score: 0.875
# --------------- Best Params ------------------
# {'C': 11.742125275677191, 'gamma': 0.0004889587009811018, 'kernel': 'rbf'}
# 0.875
AL_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1e-05
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.692680899768591e-06, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# Final best score: 0.59375
# --------------- Best Params ------------------
# {'C': 4.692680899768591e-06, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# 0.59375
# ['P001_RRE_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1e-05
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.692680899768591e-06, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# Final best score: 0.59375
# --------------- Best Params ------------------
# {'C': 4.692680899768591e-06, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# 0.59375
# ['P001_RRE_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1e-05
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.692680899768591e-06, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# Final best score: 0.59375
# --------------- Best Params ------------------
# {'C': 4.692680899768591e-06, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# 0.59375
# ['P004_GGN_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P001_RRE_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 13.167456935454494, 'gamma': 0.009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.78125
# --------------- Best Params ------------------
# {'C': 13.167456935454494, 'gamma': 0.009129425537759533, 'kernel': 'rbf'}
# 0.78125
# [4.692680899768591e-06, 4.692680899768591e-06, 4.692680899768591e-06, 4.692680899768591e-06, 13.167456935454494] [3.0101214309175212e-05, 3.0101214309175212e-05, 3.0101214309175212e-05, 3.0101214309175212e-05, 0.009129425537759533]
# 4.692680899768591e-06 3.0101214309175212e-05
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.000
# Specificity: 1.000
#
# Fold 2 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.000
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.000
# Specificity: 1.000
#
# Fold 4 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.000
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.500
# Sensitivity: 0.000
# Specificity: 1.000
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0 0 0.40980392156862744
# 0 1 0.9882352941176471
# 1 0 0.40980392156862744
# 1 1 0.9882352941176471
#  - Feature set: phonological
# ['P003_MBCB_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'P001_RRE_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.8739953278648755, 'gamma': 0.011045595986817836, 'kernel': 'rbf'}
# Final best score: 0.71875
# --------------- Best Params ------------------
# {'C': 1.8739953278648755, 'gamma': 0.011045595986817836, 'kernel': 'rbf'}
# 0.71875
# ['P002_HJTC_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1000
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 169.62487046234628, 'gamma': 1.6959629191460517e-05, 'kernel': 'rbf'}
# Final best score: 0.71875
# --------------- Best Params ------------------
# {'C': 169.62487046234628, 'gamma': 1.6959629191460517e-05, 'kernel': 'rbf'}
# 0.71875
# ['P001_RRE_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LI
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.0816014785883117, 'gamma': 0.0027970020366242126, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 3.0816014785883117, 'gamma': 0.0027970020366242126, 'kernel': 'rbf'}
# 0.75
# ['P004_GGN_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P001_RRE_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.282009864541398, 'gamma': 0.002900612949922053, 'kernel': 'rbf'}
# Final best score: 0.6875
# --------------- Best Params ------------------
# {'C': 3.282009864541398, 'gamma': 0.002900612949922053, 'kernel': 'rbf'}
# 0.6875
# [1.8739953278648755, 169.62487046234628, 56.55370667803366, 3.0816014785883117, 3.282009864541398] [0.011045595986817836, 1.6959629191460517e-05, 0.00034422299255394153, 0.0027970020366242126, 0.002900612949922053]
# 3.282009864541398 0.0027970020366242126
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 0.667
# Specificity: 0.800
#
# Fold 2 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.667
# Specificity: 0.600
#
# Fold 3 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 0.333
# Specificity: 1.000
#
# Fold 4 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.875
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.250
# Specificity: 1.000
# 0 0 0.4879892349096502
# 0 1 0.9400115340253749
# 1 0 0.7339869281045752
# 1 1 0.7339869281045752

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, roc_auc_score, confusion_matrix

def specificity_score(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    tn = cm[0, 0]
    fp = cm[0, 1]
    return tn / (tn + fp) if (tn + fp) > 0 else 0

for fold_name, fold_data in folds_data.items():
    print(f"Motor experiments for: {fold_name}")

    for feat_type, feat_df in features_dict.items():
        print(f" - Feature set: {feat_type}")

        results_df = pd.read_csv(f"results_motor_libre/{fold_name}/{feat_type}_results.csv")
        results_test_predictions_df = pd.read_csv(f"results_motor_libre/{fold_name}/{feat_type}_test_predictions.csv")

        y_test = results_test_predictions_df['y_true']
        y_pred = results_test_predictions_df['y_pred']
        y_prob = results_test_predictions_df['score']

        acc = accuracy_score(y_test, y_pred)
        sens = recall_score(y_test, y_pred)
        spec = specificity_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_prob)

        print(f"accuracy: {100*acc:.1f}")
        print(f"sensitivity: {100*sens:.1f}")
        print(f"specificity: {100*spec:.1f}")
        print(f"f1: {100*f1:.1f}")
        print(f"AUC: {auc:.2f}")

        # for metric in ['accuracy', 'sensitivity', 'specificity', 'f1']:
        #     mean_val = results_df[metric].mean()
        #     std_val = results_df[metric].std()
        #     print(f"{metric.capitalize()}: {100*mean_val:.1f} ± {100*std_val:.1f}")

        print()
# Out:
# Motor experiments for: PD_vs_HC
#  - Feature set: articulation
# accuracy: 70.9
# sensitivity: 72.5
# specificity: 69.2
# f1: 71.6
# AUC: 0.79
#
#  - Feature set: prosody
# accuracy: 62.0
# sensitivity: 55.0
# specificity: 69.2
# f1: 59.5
# AUC: 0.69
#
#  - Feature set: phonological
# accuracy: 68.4
# sensitivity: 62.5
# specificity: 74.4
# f1: 66.7
# AUC: 0.76
#
# Motor experiments for: CTR_DCL_vs_Park_DCL
#  - Feature set: articulation
# accuracy: 75.0
# sensitivity: 75.0
# specificity: 75.0
# f1: 75.0
# AUC: 0.81
#
#  - Feature set: prosody
# accuracy: 71.9
# sensitivity: 68.8
# specificity: 75.0
# f1: 71.0
# AUC: 0.73
#
#  - Feature set: phonological
# accuracy: 84.4
# sensitivity: 87.5
# specificity: 81.2
# f1: 84.8
# AUC: 0.95
#
# Motor experiments for: CTR_noDCL_vs_Park_noDCL
#  - Feature set: articulation
# accuracy: 70.2
# sensitivity: 62.5
# specificity: 78.3
# f1: 68.2
# AUC: 0.68
#
#  - Feature set: prosody
# accuracy: 59.6
# sensitivity: 62.5
# specificity: 56.5
# f1: 61.2
# AUC: 0.62
#
#  - Feature set: phonological
# accuracy: 63.8
# sensitivity: 58.3
# specificity: 69.6
# f1: 62.2
# AUC: 0.69
#
# Motor experiments for: Park_noDCL_vs_Park_DCL
#  - Feature set: articulation
# accuracy: 70.0
# sensitivity: 43.8
# specificity: 87.5
# f1: 53.8
# AUC: 0.74
#
#  - Feature set: prosody
# accuracy: 60.0
# sensitivity: 0.0
# specificity: 100.0
# f1: 0.0
# AUC: 0.41
#
#  - Feature set: phonological
# accuracy: 72.5
# sensitivity: 50.0
# specificity: 87.5
# f1: 59.3
# AUC: 0.73

# %% [markdown]
# ## Early fusion

# %%
# Create early fusion dataframe by joining on index (id)
features_early_fusion = pd.concat(features_dict.values(), axis=1)

# Run experiments
for fold_name, fold_data in folds_data.items():
    print(f"\nRunning early fusion experiments for: {fold_name}")
    
    # Run nested CV with the concatenated features
    results, test_predictions, scores = run_nested_svm_cv(fold_data, features_early_fusion)

    results_df = pd.DataFrame(results)
    test_predictions_df = pd.DataFrame(test_predictions)
    scored_df = pd.DataFrame(scores)

    # Save results
    results_df.to_csv(f"results_motor_libre/{fold_name}/earlyfusion_results.csv", index=False)
    test_predictions_df.to_csv(f"results_motor_libre/{fold_name}/earlyfusion_test_predictions.csv", index=False)
    scored_df.to_csv(f"results_motor_libre/{fold_name}/earlyfusion_scores.csv", index=False)

    all_y_true = [x['y_true'] for x in test_predictions]
    all_y_proba = [x['y_proba'] for x in test_predictions]
    all_y_pred = [x['y_pred'] for x in test_predictions]

    os.makedirs(f"results_motor_libre/{fold_name}/plots/", exist_ok=True)

    plot_ROC_curve(all_y_true, all_y_proba, f'results_motor_libre/{fold_name}/plots/roc_curve_early_fusion.png')
    plot_confusion_matrix(all_y_true, all_y_pred, f'results_motor_libre/{fold_name}/plots/confusion_matrix_early_fusion.png')
    plot_probability_density(all_y_true, all_y_proba, f'results_motor_libre/{fold_name}/plots/probability_density_early_fusion.png')
# Out:
# Running early fusion experiments for: PD_vs_HC
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C004_MLQ_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C010_MVQG_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C012_CTRE_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C015_HJOL_MOTOR_LIBRE.wav', 'C016_EALE_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C021_GDGR_MOTOR_LIBRE.wav', 'C026_JEPM_MOTOR_LIBRE.wav', 'C031_RALR_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C040_NELC_MOTOR_LIBRE.wav', 'C042_MHL_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'C047_ISV_MOTOR_LIBRE.wav', 'C049_MLLR_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P019_EA

# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.6275372946047718e-06, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# Final best score: 0.796875
# --------------- Best Params ------------------
# {'C': 3.6275372946047718e-06, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# 0.796875
# [8.921343765050313, 2.0986086379007944, 0.7779104426947422, 28.05094419291582, 3.6275372946047718e-06] [0.000576808161515076, 0.00013500342483536702, 0.0010145374482046158, 0.0022521519975341967, 0.0007439278308608544]
# 2.0986086379007944 0.0007439278308608544
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.750
# Specificity: 0.625
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.750
# Specificity: 0.625
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.375
# Specificity: 1.000
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.875
# Sensitivity: 0.750
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.667
# Sensitivity: 0.750
# Specificity: 0.571
# 0 0 0.5586082276047675
# 0 1 0.9001499423298731
# 1 0 0.8510995770857364
# 1 1 0.6197308727412534
#
# Running early fusion experiments for: CTR_DCL_vs_Park_DCL
# ['C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.5282819748826726, 'gamma': 0.0014087491475385835, 'kernel': 'rbf'}
# Final best score: 0.9583333333333334
# --------------- Best Params ------------------
# {'C': 0.5282819748826726, 'gamma': 0.0014087491475385835, 'kernel': 'rbf'}
# 0.9583333333333334
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'C003_EMAO_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.5189814782062885, 'gamma': 0.0016204835957747312, 'kernel': 'rbf'}
# Final best score: 0.875
# --------------- Best Params ------------------
# {'C': 1.5189814782062885, 'gamma': 0.0016204835957747312, 'kernel': 'rbf'}
# 0.875
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C003_EMAO_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 6.145869673706975, 'gamma': 0.003913653097580592, 'kernel': 'rbf'}
# Final best score: 0.9226190476190477
# --------------- Best Params ------------------
# {'C': 6.145869673706975, 'gamma': 0.003913653097580592, 'kernel': 'rbf'}
# 0.9226190476190477
# ['C003_EMAO_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C006_JJHN_MOTOR_LIBRE.wav', 'C007_RSL_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C019_AEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C001R_AJZP_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.7967906483133146, 'gamma': 0.0012538492877767757, 'kernel': 'rbf'}
# Final best score: 0.886904761904762
# --------------- Best Params ------------------
# {'C': 0.7967906483133146, 'gamma': 0.0012538492877767757, 'kernel': 'rbf'}
# 0.886904761904762
# ['C001R_AJZP_MOTOR_LIBRE.wav', 'C005_ABV_MOTOR_LIBRE.wav', 'C013_JIHL_MOTOR_LIBRE.wav', 'C014_MEMT_MOTOR_LIBRE.wav', 'C017_JMLC_MOTOR_LIBRE.wav', 'C020_JEG_MOTOR_LIBRE.wav', 'C033R_JJEE_MOTOR_LIBRE.wav', 'C045_LARE_MOTOR_LIBRE.wav', 'C046_GGC_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'C003_EMAO_MOTOR_LIBRE.wav', 'C011_JOMG_MOTOR_LIBRE.wav', 'C034_ADV_MOTOR_LIBRE.wav', 'C050_BOLR_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.8392857142857143
# --------------- Best Params ------------------
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.8392857142857143
# [0.5282819748826726, 1.5189814782062885, 6.145869673706975, 0.7967906483133146, 1.3167456935454493] [0.0014087491475385835, 0.0016204835957747312, 0.003913653097580592, 0.0012538492877767757, 0.0009129425537759533]
# 1.3167456935454493 0.0014087491475385835
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 1.000
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.857
# Sensitivity: 0.750
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
# 0 0 0.5283429450211456
# 0 1 0.91638985005767
# 1 0 0.91638985005767
# 1 1 0.5283429450211456
#
# Running early fusion experiments for: CTR_noDCL_vs_Park_noDCL
# ['C002_ARR_MOTOR_LIBRE.wav', 'C012_CTRE_MOTOR_LIBRE.wav', 'C016_EALE_MOTOR_LIBRE.wav', 'C021_GDGR_MOTOR_LIBRE.wav', 'C023_LGMV_MOTOR_LIBRE.wav', 'C031_RALR_MOTOR_LIBRE.wav', 'C035_JRPA_MOTOR_LIBRE.wav', 'C040_NELC_MOTOR_LIBRE.wav', 'C042_MHL_MOTOR_LIBRE.wav', 'C047_ISV_MOTOR_LIBRE.wav', 'C048_JLGC_MOTOR_LIBRE.wav', 'C049_MLLR_MOTOR_LIBRE.wav', 'C051_RAH_MOTOR_LIBRE.wav', 'P001_RRE_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'C004_MLQ_MOTOR_LIBRE.wav', 'C015_HJOL_MOTOR_LIBRE.wav', 'C025_IGHL_MOTOR_LIBRE.wav', 'C026_JEPM_MOTOR_LIBRE.wav', 'C032_LFMG_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.2949605629166843, 'gamma': 0.0037235570086999927, 'kernel': 'rbf'}
# Final best score: 0.7277777777777777
# --------------- Best Params ------------------
# {'C': 1.2949605629166843, 'gamma': 0.0037235570086999927, 'kernel': 'rbf'}
# 0.7277777777777777

# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 46.92680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.7611111111111111
# --------------- Best Params ------------------
# {'C': 46.92680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# 0.7611111111111111
# ['C010_MVQG_MOTOR_LIBRE.wav', 'C012_CTRE_MOTOR_LIBRE.wav', 'C015_HJOL_MOTOR_LIBRE.wav', 'C016_EALE_MOTOR_LIBRE.wav', 'C018_FMDV_MOTOR_LIBRE.wav', 'C021_GDGR_MOTOR_LIBRE.wav', 'C023_LGMV_MOTOR_LIBRE.wav', 'C025_IGHL_MOTOR_LIBRE.wav', 'C029_PSGL_MOTOR_LIBRE.wav', 'C031_RALR_MOTOR_LIBRE.wav', 'C032_LFMG_MOTOR_LIBRE.wav', 'C042_MHL_MOTOR_LIBRE.wav', 'C047_ISV_MOTOR_LIBRE.wav', 'C048_JLGC_MOTOR_LIBRE.wav', 'P001_RRE_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'C002_ARR_MOTOR_LIBRE.wav', 'C004_MLQ_MOTOR_LIBRE.wav', 'C024_JAVB_MOTOR_LIBRE.wav', 'C030_LMLR_MOTOR_LIBRE.wav', 'C051_RAH_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 15.189814782062886, 'gamma': 1.6204835957747313e-05, 'kernel': 'rbf'}
# Final best score: 0.7888888888888889
# --------------- Best Params ------------------
# {'C': 15.189814782062886, 'gamma': 1.6204835957747313e-05, 'kernel': 'rbf'}
# 0.7888888888888889
# [1.2949605629166843, 3.632878599687583, 115.27507630986618, 46.92680899768591, 15.189814782062886] [0.0037235570086999927, 0.00010277731500250624, 5.800908425853984e-06, 0.0003010121430917521, 1.6204835957747313e-05]
# 15.189814782062886 0.00010277731500250624
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.800
# Specificity: 0.600
#
# Fold 2 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.800
# Sensitivity: 0.600
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.667
# Sensitivity: 0.750
# Specificity: 0.600
#
# Fold 4 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.444
# Sensitivity: 0.400
# Specificity: 0.500
#
# Fold 5 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.444
# Sensitivity: 0.600
# Specificity: 0.250
# 0 0 0.6633986928104575
# 0 1 0.8114186851211073
# 1 0 0.8224913494809689
# 1 1 0.6503652441368705
#
# Running early fusion experiments for: Park_noDCL_vs_Park_DCL
# ['P003_MBCB_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'P001_RRE_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.4928071327362264, 'gamma': 0.0014922453771381407, 'kernel': 'rbf'}
# Final best score: 0.65625
# --------------- Best Params ------------------
# {'C': 3.4928071327362264, 'gamma': 0.0014922453771381407, 'kernel': 'rbf'}
# 0.65625
# ['P002_HJTC_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P013_JIRB_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P024_EAAL_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P049_GMBM_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P014_ACE_MOTOR_LIBRE.wav', 'P016_LFLS_MOTOR_LIBRE.wav', 'P018_MMCM_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P028_MCC_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P046_GVZG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 13.167456935454494, 'gamma': 9.129425537759533e-05, 'kernel': 'rbf'}
# Final best score: 0.71875
# --------------- Best Params ------------------
# {'C': 13.167456935454494, 'gamma': 9.129425537759533e-05, 'kernel': 'rbf'}
# 0.71875
# ['P001_RRE_MOTOR_LIBRE.wav', 'P002_HJTC_MOTOR_LIBRE.wav', 'P006_FAGP_MOTOR_LIBRE.wav', 'P010_EEPC_MOTOR_LIBRE.wav', 'P011_CAAA_MOTOR_LIBRE.wav', 'P012_CAMM_MOTOR_LIBRE.wav', 'P017_RAL_MOTOR_LIBRE.wav', 'P019_EAS_MOTOR_LIBRE.wav', 'P020_LARR_MOTOR_LIBRE.wav', 'P021_LAHV_MOTOR_LIBRE.wav', 'P023_JJEV_MOTOR_LIBRE.wav', 'P025_ED_MOTOR_LIBRE.wav', 'P026_JFCC_MOTOR_LIBRE.wav', 'P030_MRGT_MOTOR_LIBRE.wav', 'P031_AJAV_MOTOR_LIBRE.wav', 'P032_AFHG_MOTOR_LIBRE.wav', 'P033_JLPJ_MOTOR_LIBRE.wav', 'P034_JLPG_MOTOR_LIBRE.wav', 'P035_FGM_MOTOR_LIBRE.wav', 'P036_AVN_MOTOR_LIBRE.wav', 'P042_GEGC_MOTOR_LIBRE.wav', 'P044_CHBB_MOTOR_LIBRE.wav', 'P045_JODG_MOTOR_LIBRE.wav', 'P051_LDTR_MOTOR_LIBRE.wav', 'P003_MBCB_MOTOR_LIBRE.wav', 'P004_GGN_MOTOR_LIBRE.wav', 'P007_RAGP_MOTOR_LIBRE.wav', 'P015_FAOH_MOTOR_LIBRE.wav', 'P029_JFMG_MOTOR_LIBRE.wav', 'P037_CARS_MOTOR_LIBRE.wav', 'P040_PEEG_MOTOR_LIBRE.wav', 'P050_MEQG_MOTOR_LIBRE.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 60.893468785977504, 'gamma': 1.5379360110309122e-05, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 60.893468785977504, 'gamma': 1.5379360110309122e-05, 'kernel': 'rbf'}
# 0.75
wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 2.227358621286903, 'gamma': 0.0007220291550331277, 'kernel': 'rbf'}
# Final best score: 0.78125
# --------------- Best Params ------------------
# {'C': 2.227358621286903, 'gamma': 0.0007220291550331277, 'kernel': 'rbf'}
# 0.78125
# [3.4928071327362264, 13.167456935454494, 60.893468785977504, 4.692680899768591, 2.227358621286903] [0.0014922453771381407, 9.129425537759533e-05, 1.5379360110309122e-05, 0.0003010121430917521, 0.0007220291550331277]
# 4.692680899768591 0.0003010121430917521
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.875
# Sensitivity: 1.000
# Specificity: 0.800
#
# Fold 2 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.333
# Specificity: 0.800
#
# Fold 3 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.333
# Specificity: 0.800
#
# Fold 4 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.875
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.500
# Sensitivity: 0.000
# Specificity: 1.000
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0 0 0.4879892349096502
# 0 1 0.9400115340253749
# 1 0 0.692156862745098
# 1 1 0.7782006920415225

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Reading experiments for early fusion: {fold_name}")

    # Save results
    results_df = pd.read_csv(f"results_motor_libre/{fold_name}/earlyfusion_results.csv")
    results_test_predictions_df = pd.read_csv(f"results_motor_libre/{fold_name}/earlyfusion_test_predictions.csv")

    y_test = results_test_predictions_df['y_true']
    y_pred = results_test_predictions_df['y_pred']
    y_prob = results_test_predictions_df['score']

    acc = accuracy_score(y_test, y_pred)
    sens = recall_score(y_test, y_pred)
    spec = specificity_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    print(f"accuracy: {100*acc:.1f}")
    print(f"sensitivity: {100*sens:.1f}")
    print(f"specificity: {100*spec:.1f}")
    print(f"f1: {100*f1:.1f}")
    print(f"AUC: {auc:.2f}")

    
    # for metric in ['accuracy', 'sensitivity', 'specificity', 'f1']:
    #     mean_val = results_df[metric].mean()
    #     std_val = results_df[metric].std()
    #     print(f"{metric.capitalize()}: {100*mean_val:.1f} ± {100*std_val:.1f}")
    
    print()
# Out:
# Reading experiments for early fusion: PD_vs_HC
# accuracy: 72.2
# sensitivity: 67.5
# specificity: 76.9
# f1: 71.1
# AUC: 0.77
#
# Reading experiments for early fusion: CTR_DCL_vs_Park_DCL
# accuracy: 81.2
# sensitivity: 81.2
# specificity: 81.2
# f1: 81.2
# AUC: 0.88
#
# Reading experiments for early fusion: CTR_noDCL_vs_Park_noDCL
# accuracy: 61.7
# sensitivity: 62.5
# specificity: 60.9
# f1: 62.5
# AUC: 0.69
#
# Reading experiments for early fusion: Park_noDCL_vs_Park_DCL
# accuracy: 70.0
# sensitivity: 43.8
# specificity: 87.5
# f1: 53.8
# AUC: 0.75

# %% [markdown]
# ## Late fusion

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Running experiments for: {fold_name}")

    scores_artic_df = pd.read_csv(f"results_motor_libre/{fold_name}/articulation_scores.csv")
    scores_phon_df = pd.read_csv(f"results_motor_libre/{fold_name}/phonological_scores.csv")
    scores_pros_df = pd.read_csv(f"results_motor_libre/{fold_name}/prosody_scores.csv")
        
    # Select and rename score columns while keeping id, outer_fold, and set_type
    artic_scores = scores_artic_df[['id', 'outer_fold', 'set_type', 'score']].rename(columns={'score': 'artic_score'})
    phon_scores = scores_phon_df[['id', 'outer_fold', 'set_type', 'score']].rename(columns={'score': 'phon_score'})
    pros_scores = scores_pros_df[['id', 'outer_fold', 'set_type', 'score']].rename(columns={'score': 'pros_score'})

    # Merge the dataframes
    merged_scores_df = artic_scores.merge(
        phon_scores, 
        on=['id', 'outer_fold', 'set_type']
    ).merge(
        pros_scores,
        on=['id', 'outer_fold', 'set_type']
    )

    results, test_predictions, scores = run_late_fusion(fold_data, merged_scores_df)
    
    results_df = pd.DataFrame(results)
    test_predictions_df = pd.DataFrame(test_predictions)
    scored_df = pd.DataFrame(scores)

    # Save results
    results_df.to_csv(f"results_motor_libre/{fold_name}/latefusion_results.csv", index=False)
    test_predictions_df.to_csv(f"results_motor_libre/{fold_name}/latefusion_test_predictions.csv", index=False)
    merged_scores_df.to_csv(f"results_motor_libre/{fold_name}/latefusion_scores.csv", index=False)

    all_y_true = [x['y_true'] for x in test_predictions]
    all_y_proba = [x['y_proba'] for x in test_predictions]
    all_y_pred = [x['y_pred'] for x in test_predictions]

    os.makedirs(f"results_motor_libre/{fold_name}/plots/", exist_ok=True)

    plot_ROC_curve(all_y_true, all_y_proba, f'results_motor_libre/{fold_name}/plots/roc_curve_late_fusion.png')
    plot_confusion_matrix(all_y_true, all_y_pred, f'results_motor_libre/{fold_name}/plots/confusion_matrix_late_fusion.png')
    plot_probability_density(all_y_true, all_y_proba, f'results_motor_libre/{fold_name}/plots/probability_density_late_fusion.png')
# Out:
# Running experiments for: PD_vs_HC
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 22
#      13 # Merge the dataframes
#      14 merged_scores_df = artic_scores.merge(
#      15     phon_scores,
#      16     on=['id', 'outer_fold', 'set_type']
#    (...)
#      19     on=['id', 'outer_fold', 'set_type']
#      20 )
# ---> 22 results, test_predictions, scores = run_late_fusion(fold_data, merged_scores_df)
#      24 results_df = pd.DataFrame(results)
#      25 test_predictions_df = pd.DataFrame(test_predictions)
#
# Cell In[2], line 376, in run_late_fusion(fold_dict, scores_df, random_state, type)
#     373     val_idx = [i for i, id_ in enumerate(train_ids) if id_ in val_ids]
#     374     inner_folds.append((train_idx, val_idx))
# --> 376 model = train_randomized_inner_model(X_train, y_train, inner_folds, random_state)
#     378 print("--------------- Best Params ------------------")
#     379 print(model.best_params_)
#
# Cell In[2], line 41, in train_randomized_inner_model(X_train, y_train, inner_folds, random_state, n_iter)
#      32 svc1=SVC(random_state=random_state)
#      33 grid_search = GridSearchCV(
#      34     svc1,
#      35     param_grid,
#    (...)
#      39     verbose=1
#      40 )
# ---> 41 grid_search.fit(X_train, y_train)
#      43 best_C = grid_search.best_params_['C']
#      44 best_gamma = grid_search.best_params_['gamma']
#
# File c:\Users\gita2\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\gita2\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\gita2\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\gita2\anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\gita2\anaconda3\lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\gita2\anaconda3\lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\gita2\anaconda3\lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\gita2\anaconda3\lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File c:\Users\gita2\anaconda3\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Libre experiments for late fusion: {fold_name}")

    results_df = pd.read_csv(f"results_motor_libre/{fold_name}/latefusion_results.csv")
    results_test_predictions_df = pd.read_csv(f"results_motor_libre/{fold_name}/latefusion_test_predictions.csv")

    y_test = results_test_predictions_df['y_true']
    y_pred = results_test_predictions_df['y_pred']
    y_prob = results_test_predictions_df['score']

    acc = accuracy_score(y_test, y_pred)
    sens = recall_score(y_test, y_pred)
    spec = specificity_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_prob)

    print(f"accuracy: {100*acc:.1f}")
    print(f"sensitivity: {100*sens:.1f}")
    print(f"specificity: {100*spec:.1f}")
    print(f"f1: {100*f1:.1f}")
    print(f"AUC: {auc:.2f}")

    # for metric in ['accuracy', 'sensitivity', 'specificity', 'f1']:
    #     mean_val = results_df[metric].mean()
    #     std_val = results_df[metric].std()
    #     print(f"{metric.capitalize()}: {100*mean_val:.1f} ± {100*std_val:.1f}")        
    
    print()
# Out:
# Libre experiments for late fusion: PD_vs_HC
# accuracy: 69.6
# sensitivity: 75.0
# specificity: 64.1
# f1: 71.4
# AUC: 0.76
#
# Libre experiments for late fusion: CTR_DCL_vs_Park_DCL
# accuracy: 84.4
# sensitivity: 87.5
# specificity: 81.2
# f1: 84.8
# AUC: 0.89
#
# Libre experiments for late fusion: CTR_noDCL_vs_Park_noDCL
# accuracy: 59.6
# sensitivity: 62.5
# specificity: 56.5
# f1: 61.2
# AUC: 0.74
#
# Libre experiments for late fusion: Park_noDCL_vs_Park_DCL
# accuracy: 60.0
# sensitivity: 62.5
# specificity: 58.3
# f1: 55.6
# AUC: 0.70

# %% [markdown]
# # Reading

# %%
# Load all folds
folds_paths = {
    "CTR_DCL_vs_Park_DCL": "folds/CTR_DCL_vs_Park_DCL_folds.json",
    "CTR_noDCL_vs_Park_noDCL": "folds/CTR_noDCL_vs_Park_noDCL_folds.json",
    "Park_noDCL_vs_Park_DCL": "folds/Park_noDCL_vs_Park_DCL_folds.json",
    "PD_vs_HC": "folds/PD_vs_HC_folds.json"
}

folds_data = {}
for name, path in folds_paths.items():
    with open(path, "r") as f:
        folds_data[name] = json.load(f)

# Load feature sets
features_dict = {
    "articulation": pd.read_csv('features/articulationfeatures.csv').set_index('id'),
    "prosody": pd.read_csv('features/prosodyfeatures.csv').set_index('id'),
    "phonological": pd.read_csv('features/phonologicalfeatures.csv').set_index('id')
}

for fold_name, fold_data in folds_data.items():
    print(f"Running experiments for: {fold_name}")
    
    # Create directory for this fold if it doesn't exist
    os.makedirs(f"results_motor_lectura/{fold_name}", exist_ok=True)

    for feat_type, feat_df in features_dict.items():
        print(f" - Feature set: {feat_type}")
        
        results, test_predictions, scores = run_nested_svm_cv(fold_data, feat_df, type='_MOTOR_LECTURA.wav')
        
        results_df = pd.DataFrame(results)
        test_predictions_df = pd.DataFrame(test_predictions)
        scored_df = pd.DataFrame(scores)

        # Save results
        results_df.to_csv(f"results_motor_lectura/{fold_name}/{feat_type}_results.csv", index=False)
        test_predictions_df.to_csv(f"results_motor_lectura/{fold_name}/{feat_type}_test_predictions.csv", index=False)
        scored_df.to_csv(f"results_motor_lectura/{fold_name}/{feat_type}_scores.csv", index=False)

        all_y_true = [x['y_true'] for x in test_predictions]
        all_y_proba = [x['y_proba'] for x in test_predictions]
        all_y_pred = [x['y_pred'] for x in test_predictions]

        os.makedirs(f"results_motor_lectura/{fold_name}/plots/", exist_ok=True)

        plot_ROC_curve(all_y_true, all_y_proba, f'results_motor_lectura/{fold_name}/plots/roc_curve_{feat_type}.png')
        plot_confusion_matrix(all_y_true, all_y_pred, f'results_motor_lectura/{fold_name}/plots/confusion_matrix_{feat_type}.png')
        plot_probability_density(all_y_true, all_y_proba, f'results_motor_lectura/{fold_name}/plots/probability_density_{feat_type}.png')
# Out:
# Running experiments for: CTR_DCL_vs_Park_DCL
#  - Feature set: articulation
# ['C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.3627537294604771, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# Final best score: 0.9583333333333334
# --------------- Best Params ------------------
# {'C': 0.3627537294604771, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# 0.9583333333333334
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.9166666666666667
# --------------- Best Params ------------------
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.9166666666666667
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 13.167456935454494, 'gamma': 9.129425537759533e-05, 'kernel': 'rbf'}
# Final best score: 0.9285714285714286
# --------------- Best Params ------------------
# {'C': 13.167456935454494, 'gamma': 9.129425537759533e-05, 'kernel': 'rbf'}
# 0.9285714285714286
# ['C003_EMAO_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C001R_AJZP_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.692680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.880952380952381
# --------------- Best Params ------------------
# {'C': 4.692680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# 0.880952380952381
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.44446140167806814, 'gamma': 0.0020972026672943325, 'kernel': 'rbf'}
# Final best score: 0.886904761904762
# --------------- Best Params ------------------
# {'C': 0.44446140167806814, 'gamma': 0.0020972026672943325, 'kernel': 'rbf'}
# 0.886904761904762
# [0.3627537294604771, 1.3167456935454493, 13.167456935454494, 4.692680899768591, 0.44446140167806814] [0.0007439278308608544, 0.0009129425537759533, 9.129425537759533e-05, 0.0003010121430917521, 0.0020972026672943325]
# 1.3167456935454493 0.0007439278308608544
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.571
# Sensitivity: 0.667
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.857
# Sensitivity: 0.750
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 1.000
# Sensitivity: 1.000
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 1.000
# Sensitivity: 1.000
# Specificity: 1.000
# 0 0 0.5283429450211456
# 0 1 0.91638985005767
# 1 0 0.9400115340253749
# 1 1 0.4879892349096502
#  - Feature set: prosody
# ['C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.5577315371944382, 'gamma': 0.0026355234573318897, 'kernel': 'rbf'}
# Final best score: 0.6845238095238095
# --------------- Best Params ------------------
# {'C': 1.5577315371944382, 'gamma': 0.0026355234573318897, 'kernel': 'rbf'}
# 0.6845238095238095
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 5.655370667803367, 'gamma': 0.0034422299255394153, 'kernel': 'rbf'}
# Final best score: 0.7976190476190477
# --------------- Best Params ------------------
# {'C': 5.655370667803367, 'gamma': 0.0034422299255394153, 'kernel': 'rbf'}
# 0.7976190476190477
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 7.912237979817975, 'gamma': 0.00020438859950790576, 'kernel': 'rbf'}
# Final best score: 0.8095238095238095
# --------------- Best Params ------------------
# {'C': 7.912237979817975, 'gamma': 0.00020438859950790576, 'kernel': 'rbf'}
# 0.8095238095238095
# ['C003_EMAO_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C001R_AJZP_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 7.160932369329037, 'gamma': 0.0006961843775511993, 'kernel': 'rbf'}
# Final best score: 0.8095238095238095
# --------------- Best Params ------------------
# {'C': 7.160932369329037, 'gamma': 0.0006961843775511993, 'kernel': 'rbf'}
# 0.8095238095238095
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 131.67456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.6011904761904762
# --------------- Best Params ------------------
# {'C': 131.67456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.6011904761904762
# [1.5577315371944382, 5.655370667803367, 7.912237979817975, 7.160932369329037, 131.67456935454493] [0.0026355234573318897, 0.0034422299255394153, 0.00020438859950790576, 0.0006961843775511993, 0.0009129425537759533]
# 7.160932369329037 0.0009129425537759533
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.857
# Sensitivity: 1.000
# Specificity: 0.750
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 0.500
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.333
# Sensitivity: 0.333
# Specificity: 0.333
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
# 0 0 0.5686966551326413
# 0 1 0.8925913110342176
# 1 0 0.8576509034986544
# 1 1 0.609519415609381
#  - Feature set: phonological
# ['C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 0.875
# --------------- Best Params ------------------
# {'C': 4.692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 0.875
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 2.8050944192915823, 'gamma': 0.022521519975341967, 'kernel': 'rbf'}
# Final best score: 0.7559523809523809
# --------------- Best Params ------------------
# {'C': 2.8050944192915823, 'gamma': 0.022521519975341967, 'kernel': 'rbf'}
# 0.7559523809523809
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.9190821536272645, 'gamma': 0.012312500617045903, 'kernel': 'rbf'}
# Final best score: 0.8809523809523809
# --------------- Best Params ------------------
# {'C': 0.9190821536272645, 'gamma': 0.012312500617045903, 'kernel': 'rbf'}
# 0.8809523809523809
# ['C003_EMAO_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C001R_AJZP_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 56.55370667803366, 'gamma': 0.00034422299255394153, 'kernel': 'rbf'}
# Final best score: 0.8511904761904762
# --------------- Best Params ------------------
# {'C': 56.55370667803366, 'gamma': 0.00034422299255394153, 'kernel': 'rbf'}
# 0.8511904761904762
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 18.22190046469857, 'gamma': 6.324155711397736e-05, 'kernel': 'rbf'}
# Final best score: 0.8035714285714285
# --------------- Best Params ------------------
# {'C': 18.22190046469857, 'gamma': 6.324155711397736e-05, 'kernel': 'rbf'}
# 0.8035714285714285
# [4.692680899768591, 2.8050944192915823, 0.9190821536272645, 56.55370667803366, 18.22190046469857] [0.03010121430917521, 0.022521519975341967, 0.012312500617045903, 0.00034422299255394153, 6.324155711397736e-05]
# 4.692680899768591 0.012312500617045903
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.571
# Sensitivity: 0.667
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 0.500
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 1.000
# Sensitivity: 1.000
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 1.000
# Sensitivity: 1.000
# Specificity: 1.000
# 0 0 0.5283429450211456
# 0 1 0.91638985005767
# 1 0 0.91638985005767
# 1 1 0.5283429450211456
# Running experiments for: CTR_noDCL_vs_Park_noDCL
#  - Feature set: articulation
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 2.1811325693966133, 'gamma': 0.0015135621919309032, 'kernel': 'rbf'}
# Final best score: 0.7277777777777777
# --------------- Best Params ------------------
# {'C': 2.1811325693966133, 'gamma': 0.0015135621919309032, 'kernel': 'rbf'}
# 0.7277777777777777
# ['C002_ARR_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1000
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1316.7456935454493, 'gamma': 9.129425537759534e-06, 'kernel': 'rbf'}
# Final best score: 0.7027777777777777
# --------------- Best Params ------------------
# {'C': 1316.7456935454493, 'gamma': 9.129425537759534e-06, 'kernel': 'rbf'}
# 0.7027777777777777
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 5.655370667803367, 'gamma': 0.00034422299255394153, 'kernel': 'rbf'}
# Final best score: 0.7333333333333333
# --------------- Best Params ------------------
# {'C': 5.655370667803367, 'gamma': 0.00034422299255394153, 'kernel': 'rbf'}
# 0.7333333333333333
# ['C004_MLQ_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 43.94063891516504, 'gamma': 4.093574204392867e-05, 'kernel': 'rbf'}
# Final best score: 0.8138888888888889
# --------------- Best Params ------------------
# {'C': 43.94063891516504, 'gamma': 4.093574204392867e-05, 'kernel': 'rbf'}
# 0.8138888888888889
# ['C010_MVQG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 46.92680899768591, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# Final best score: 0.7666666666666666
# --------------- Best Params ------------------
# {'C': 46.92680899768591, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# 0.7666666666666666
# [2.1811325693966133, 1316.7456935454493, 5.655370667803367, 43.94063891516504, 46.92680899768591] [0.0015135621919309032, 9.129425537759534e-06, 0.00034422299255394153, 4.093574204392867e-05, 3.0101214309175212e-05]
# 43.94063891516504 4.093574204392867e-05
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.600
# Specificity: 0.800
#
# Fold 2 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.800
# Specificity: 0.600
#
# Fold 3 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.778
# Sensitivity: 0.750
# Specificity: 0.800
#
# Fold 4 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.556
# Sensitivity: 0.600
# Specificity: 0.500
#
# Fold 5 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.556
# Sensitivity: 0.800
# Specificity: 0.250
# 0 0 0.6633986928104575
# 0 1 0.8114186851211073
# 1 0 0.8707535563244906
# 1 1 0.5967550941945405
#  - Feature set: prosody
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 46.92680899768591, 'gamma': 0.003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.7333333333333333
# --------------- Best Params ------------------
# {'C': 46.92680899768591, 'gamma': 0.003010121430917521, 'kernel': 'rbf'}
# 0.7333333333333333
# ['C002_ARR_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.8597305690237871, 'gamma': 0.011409958207372404, 'kernel': 'rbf'}
# Final best score: 0.7333333333333333
# --------------- Best Params ------------------
# {'C': 0.8597305690237871, 'gamma': 0.011409958207372404, 'kernel': 'rbf'}
# 0.7333333333333333
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1000
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 200.67898874966338, 'gamma': 2.0261142283225706e-05, 'kernel': 'rbf'}
# Final best score: 0.6888888888888889
# --------------- Best Params ------------------
# {'C': 200.67898874966338, 'gamma': 2.0261142283225706e-05, 'kernel': 'rbf'}
# 0.6888888888888889
# ['C004_MLQ_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 46.92680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.788888888888889
# --------------- Best Params ------------------
# {'C': 46.92680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# 0.788888888888889
# ['C010_MVQG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 8.975047213097605, 'gamma': 0.0004756384975640855, 'kernel': 'rbf'}
# Final best score: 0.7638888888888888
# --------------- Best Params ------------------
# {'C': 8.975047213097605, 'gamma': 0.0004756384975640855, 'kernel': 'rbf'}
# 0.7638888888888888
# [46.92680899768591, 0.8597305690237871, 200.67898874966338, 46.92680899768591, 8.975047213097605] [0.003010121430917521, 0.011409958207372404, 2.0261142283225706e-05, 0.0003010121430917521, 0.0004756384975640855]
# 46.92680899768591 0.0004756384975640855
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.600
# Specificity: 0.800
#
# Fold 2 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.800
# Sensitivity: 0.800
# Specificity: 0.800
#
# Fold 3 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.444
# Sensitivity: 0.500
# Specificity: 0.400
#
# Fold 4 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.444
# Sensitivity: 0.600
# Specificity: 0.250
#
# Fold 5 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.556
# Sensitivity: 0.800
# Specificity: 0.250
# 0 0 0.7209150326797386
# 0 1 0.7505190311418686
# 1 0 0.8467320261437908
# 1 1 0.6248366013071895
#  - Feature set: phonological
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.9404920709825931, 'gamma': 0.006985196328296385, 'kernel': 'rbf'}
# Final best score: 0.7333333333333333
# --------------- Best Params ------------------
# {'C': 0.9404920709825931, 'gamma': 0.006985196328296385, 'kernel': 'rbf'}
# 0.7333333333333333
# ['C002_ARR_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 46.92680899768591, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# Final best score: 0.7527777777777778
# --------------- Best Params ------------------
# {'C': 46.92680899768591, 'gamma': 3.0101214309175212e-05, 'kernel': 'rbf'}
# 0.7527777777777778
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.9504040195913728, 'gamma': 0.005417025065931134, 'kernel': 'rbf'}
# Final best score: 0.6555555555555554
# --------------- Best Params ------------------
# {'C': 0.9504040195913728, 'gamma': 0.005417025065931134, 'kernel': 'rbf'}
# 0.6555555555555554
# ['C004_MLQ_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.711111111111111
# --------------- Best Params ------------------
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.711111111111111
# ...
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1e-05
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.3167456935454495e-05, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.625
# --------------- Best Params ------------------
# {'C': 1.3167456935454495e-05, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.625
# [0.6765179657972332, 7.121712524346369, 23.06774427648427, 0.6266069481821096, 1.3167456935454495e-05] [0.006414503320943712, 0.005712879886799935, 0.0010026699194828847, 0.00782294585687126, 0.0009129425537759533]
# 0.6765179657972332 0.005712879886799935
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.688
# Sensitivity: 0.625
# Specificity: 0.750
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.562
# Sensitivity: 0.375
# Specificity: 0.750
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.812
# Sensitivity: 0.875
# Specificity: 0.750
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.750
# Specificity: 0.750
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.733
# Sensitivity: 0.500
# Specificity: 1.000
# 0 0 0.540953479430988
# 0 1 0.9104844290657439
# 1 0 0.8224913494809689
# 1 1 0.6503652441368705
#  - Feature set: phonological
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.764557865240934, 'gamma': 0.004412269995298702, 'kernel': 'rbf'}
# Final best score: 0.778125
# --------------- Best Params ------------------
# {'C': 1.764557865240934, 'gamma': 0.004412269995298702, 'kernel': 'rbf'}
# 0.778125
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 16.47348291303566, 'gamma': 0.00022642426492862315, 'kernel': 'rbf'}
# Final best score: 0.8739583333333334
# --------------- Best Params ------------------
# {'C': 16.47348291303566, 'gamma': 0.00022642426492862315, 'kernel': 'rbf'}
# 0.8739583333333334
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 41.67336709307531, 'gamma': 0.00026701379243993266, 'kernel': 'rbf'}
# Final best score: 0.8552083333333333
# --------------- Best Params ------------------
# {'C': 41.67336709307531, 'gamma': 0.00026701379243993266, 'kernel': 'rbf'}
# 0.8552083333333333
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.9190821536272645, 'gamma': 0.0012312500617045904, 'kernel': 'rbf'}
# Final best score: 0.7791666666666667
# --------------- Best Params ------------------
# {'C': 0.9190821536272645, 'gamma': 0.0012312500617045904, 'kernel': 'rbf'}
# 0.7791666666666667
# ['C003_EMAO_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.394063891516504, 'gamma': 0.0004093574204392867, 'kernel': 'rbf'}
# Final best score: 0.8125
# --------------- Best Params ------------------
# {'C': 4.394063891516504, 'gamma': 0.0004093574204392867, 'kernel': 'rbf'}
# 0.8125
# [1.764557865240934, 16.47348291303566, 41.67336709307531, 0.9190821536272645, 4.394063891516504] [0.004412269995298702, 0.00022642426492862315, 0.00026701379243993266, 0.0012312500617045904, 0.0004093574204392867]
# 4.394063891516504 0.0004093574204392867
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.938
# Sensitivity: 1.000
# Specificity: 0.875
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.625
# Specificity: 0.875
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.625
# Specificity: 0.875
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.625
# Specificity: 0.875
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.867
# Sensitivity: 0.750
# Specificity: 1.000
# 0 0 0.4753787004998078
# 0 1 0.9490503652441369
# 1 0 0.8794886582083814
# 1 1 0.5865436370626682

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Reading experiments for: {fold_name}")

    for feat_type, feat_df in features_dict.items():
        print(f" - Feature set: {feat_type}")

        # Save results
        results_df = pd.read_csv(f"results_motor_lectura/{fold_name}/{feat_type}_results.csv")

        results_test_predictions_df = pd.read_csv(f"results_motor_lectura/{fold_name}/{feat_type}_test_predictions.csv")

        for metric in ['accuracy', 'sensitivity', 'specificity', 'f1']:
            mean_val = results_df[metric].mean()
            std_val = results_df[metric].std()
            print(f"{metric.capitalize()}: {100*mean_val:.1f} ± {100*std_val:.1f}")        
        print()
# Out:
# Reading experiments for: CTR_DCL_vs_Park_DCL
#  - Feature set: articulation
# Accuracy: 85.2 ± 17.5
# Sensitivity: 88.3 ± 16.2
# Specificity: 83.3 ± 23.6
# F1: 85.7 ± 17.5
#
#  - Feature set: prosody
# Accuracy: 71.4 ± 22.0
# Sensitivity: 70.0 ± 29.8
# Specificity: 75.0 ± 27.6
# F1: 70.3 ± 22.1
#
#  - Feature set: phonological
# Accuracy: 82.4 ± 18.6
# Sensitivity: 83.3 ± 23.6
# Specificity: 83.3 ± 23.6
# F1: 81.9 ± 19.5
#
# Reading experiments for: CTR_noDCL_vs_Park_noDCL
#  - Feature set: articulation
# Accuracy: 65.8 ± 9.9
# Sensitivity: 71.0 ± 10.2
# Specificity: 59.0 ± 23.0
# F1: 68.2 ± 5.9
#
#  - Feature set: prosody
# Accuracy: 58.9 ± 15.8
# Sensitivity: 66.0 ± 13.4
# Specificity: 50.0 ± 28.1
# F1: 62.5 ± 13.5
#
#  - Feature set: phonological
# Accuracy: 70.4 ± 10.9
# Sensitivity: 55.0 ± 15.0
# Specificity: 87.0 ± 18.6
# F1: 65.3 ± 12.0
#
# Reading experiments for: Park_noDCL_vs_Park_DCL
#  - Feature set: articulation
# Accuracy: 67.5 ± 14.3
# Sensitivity: 51.7 ± 20.7
# Specificity: 80.0 ± 24.5
# F1: 55.3 ± 17.6
#
#  - Feature set: prosody
# Accuracy: 50.0 ± 19.8
# Sensitivity: 38.3 ± 43.9
# Specificity: 58.0 ± 24.9
# F1: 30.7 ± 32.5
#
#  - Feature set: phonological
# Accuracy: 62.5 ± 23.4
# Sensitivity: 60.0 ± 43.5
# Specificity: 67.0 ± 22.2
# F1: 51.4 ± 37.4
#
# Reading experiments for: PD_vs_HC
#  - Feature set: articulation
# Accuracy: 82.2 ± 13.6
# Sensitivity: 82.5 ± 11.2
# Specificity: 82.1 ± 18.9
# F1: 82.8 ± 12.2
#
#  - Feature set: prosody
# Accuracy: 70.9 ± 9.3
# Sensitivity: 62.5 ± 19.8
# Specificity: 80.0 ± 11.2
# F1: 67.4 ± 13.5
#
#  - Feature set: phonological
# Accuracy: 81.1 ± 8.7
# Sensitivity: 72.5 ± 16.3
# Specificity: 90.0 ± 5.6
# F1: 78.8 ± 10.6

# %% [markdown]
# ## Early fusion

# %%
# Create early fusion dataframe by joining on index (id)
features_early_fusion = pd.concat(features_dict.values(), axis=1)

# Run experiments
for fold_name, fold_data in folds_data.items():
    print(f"\nRunning early fusion experiments for: {fold_name}")
    
    # Run nested CV with the concatenated features
    results, test_predictions, scores = run_nested_svm_cv(fold_data, features_early_fusion, type='_MOTOR_LECTURA.wav')
    
    results_df = pd.DataFrame(results)
    test_predictions_df = pd.DataFrame(test_predictions)
    scored_df = pd.DataFrame(scores)

    # Save results
    results_df.to_csv(f"results_motor_lectura/{fold_name}/earlyfusion_results.csv", index=False)
    test_predictions_df.to_csv(f"results_motor_lectura/{fold_name}/earlyfusion_test_predictions.csv", index=False)
    scored_df.to_csv(f"results_motor_lectura/{fold_name}/earlyfusion_scores.csv", index=False)

    all_y_true = [x['y_true'] for x in test_predictions]
    all_y_proba = [x['y_proba'] for x in test_predictions]
    all_y_pred = [x['y_pred'] for x in test_predictions]

    os.makedirs(f"results_motor_lectura/{fold_name}/plots/", exist_ok=True)

    plot_ROC_curve(all_y_true, all_y_proba, f'results_motor_lectura/{fold_name}/plots/roc_curve_early_fusion.png')
    plot_confusion_matrix(all_y_true, all_y_pred, f'results_motor_lectura/{fold_name}/plots/confusion_matrix_early_fusion.png')
    plot_probability_density(all_y_true, all_y_proba, f'results_motor_lectura/{fold_name}/plots/probability_density_early_fusion.png')
# Out:
# Running early fusion experiments for: CTR_DCL_vs_Park_DCL
# ['C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 7.967906483133146, 'gamma': 1.2538492877767758e-05, 'kernel': 'rbf'}
# Final best score: 0.9583333333333334
# --------------- Best Params ------------------
# {'C': 7.967906483133146, 'gamma': 1.2538492877767758e-05, 'kernel': 'rbf'}
# 0.9583333333333334
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# Final best score: 0.9166666666666667
# --------------- Best Params ------------------
# {'C': 1.3167456935454493, 'gamma': 0.0009129425537759533, 'kernel': 'rbf'}
# 0.9166666666666667
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.692680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.886904761904762
# --------------- Best Params ------------------
# {'C': 4.692680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# 0.886904761904762
# ['C003_EMAO_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C001R_AJZP_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.627537294604771, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# Final best score: 0.880952380952381
# --------------- Best Params ------------------
# {'C': 3.627537294604771, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# 0.880952380952381
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 6.08934687859775, 'gamma': 0.0001537936011030912, 'kernel': 'rbf'}
# Final best score: 0.8511904761904762
# --------------- Best Params ------------------
# {'C': 6.08934687859775, 'gamma': 0.0001537936011030912, 'kernel': 'rbf'}
# 0.8511904761904762
# [7.967906483133146, 1.3167456935454493, 4.692680899768591, 3.627537294604771, 6.08934687859775] [1.2538492877767758e-05, 0.0009129425537759533, 0.0003010121430917521, 0.0007439278308608544, 0.0001537936011030912]
# 4.692680899768591 0.0003010121430917521
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.571
# Sensitivity: 0.667
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 0.500
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 1.000
# Sensitivity: 1.000
# Specificity: 1.000
# 0 0 0.5283429450211456
# 0 1 0.91638985005767
# 1 0 0.8925913110342176
# 1 1 0.5686966551326413
#
# Running early fusion experiments for: CTR_noDCL_vs_Park_noDCL
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.6301943751443413, 'gamma': 0.003469835664491751, 'kernel': 'rbf'}
# Final best score: 0.7305555555555555
# --------------- Best Params ------------------
# {'C': 3.6301943751443413, 'gamma': 0.003469835664491751, 'kernel': 'rbf'}
# 0.7305555555555555
# ['C002_ARR_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1000
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1786.4295433546752, 'gamma': 2.38687625248947e-06, 'kernel': 'rbf'}
# Final best score: 0.7555555555555555
# --------------- Best Params ------------------
# {'C': 1786.4295433546752, 'gamma': 2.38687625248947e-06, 'kernel': 'rbf'}
# 0.7555555555555555
# ['C002_ARR_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 46.92680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# Final best score: 0.7055555555555556
# --------------- Best Params ------------------
# {'C': 46.92680899768591, 'gamma': 0.0003010121430917521, 'kernel': 'rbf'}
# 0.7055555555555556
# ['C004_MLQ_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 28.172554553871517, 'gamma': 8.567824455775445e-05, 'kernel': 'rbf'}
# Final best score: 0.7638888888888888
# --------------- Best Params ------------------
# {'C': 28.172554553871517, 'gamma': 8.567824455775445e-05, 'kernel': 'rbf'}
# 0.7638888888888888
# ['C010_MVQG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 4.628196568683196, 'gamma': 3.9353208680308684e-05, 'kernel': 'rbf'}
# Final best score: 0.7638888888888888
# --------------- Best Params ------------------
# {'C': 4.628196568683196, 'gamma': 3.9353208680308684e-05, 'kernel': 'rbf'}
# 0.7638888888888888
# [3.6301943751443413, 1786.4295433546752, 46.92680899768591, 28.172554553871517, 4.628196568683196] [0.003469835664491751, 2.38687625248947e-06, 0.0003010121430917521, 8.567824455775445e-05, 3.9353208680308684e-05]
# 28.172554553871517 8.567824455775445e-05
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.600
# Sensitivity: 0.600
# Specificity: 0.600
#
# Fold 2 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.800
# Specificity: 0.600
#
# Fold 3 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.778
# Sensitivity: 0.750
# Specificity: 0.800
#
# Fold 4 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.444
# Sensitivity: 0.600
# Specificity: 0.250
#
# Fold 5 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.444
# Sensitivity: 0.800
# Specificity: 0.000
# 0 0 0.7505190311418686
# 0 1 0.7209150326797386
# 1 0 0.8707535563244906
# 1 1 0.5967550941945405
#
# Running early fusion experiments for: Park_noDCL_vs_Park_DCL
# ['P003_MBCB_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.627537294604771, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 3.627537294604771, 'gamma': 0.0007439278308608544, 'kernel': 'rbf'}
# 0.75
# ['P002_HJTC_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 3.1064814560107075, 'gamma': 0.00021089114354403584, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 3.1064814560107075, 'gamma': 0.00021089114354403584, 'kernel': 'rbf'}
# 0.75
# ['P001_RRE_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 2.4622525594093334, 'gamma': 0.00029949562537397764, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 2.4622525594093334, 'gamma': 0.00029949562537397764, 'kernel': 'rbf'}
# 0.75
# ['P001_RRE_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1000
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 565.5370667803367, 'gamma': 3.4422299255394154e-06, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 565.5370667803367, 'gamma': 3.4422299255394154e-06, 'kernel': 'rbf'}
# 0.75
# ['P004_GGN_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.786429543354675, 'gamma': 0.000238687625248947, 'kernel': 'rbf'}
# Final best score: 0.75
# --------------- Best Params ------------------
# {'C': 1.786429543354675, 'gamma': 0.000238687625248947, 'kernel': 'rbf'}
# 0.75
# [3.627537294604771, 3.1064814560107075, 2.4622525594093334, 565.5370667803367, 1.786429543354675] [0.0007439278308608544, 0.00021089114354403584, 0.00029949562537397764, 3.4422299255394154e-06, 0.000238687625248947]
# 3.1064814560107075 0.000238687625248947
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.667
# Specificity: 0.600
#
# Fold 2 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.333
# Specificity: 0.800
#
# Fold 3 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 0.667
# Specificity: 0.800
#
# Fold 4 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 0.333
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.500
# Sensitivity: 0.000
# Specificity: 1.000
# 0 0 0.5157324106113034
# 0 1 0.9252479815455594
# 1 0 0.6503652441368705
# 1 1 0.8224913494809689
# c:\Users\gita2\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Running early fusion experiments for: PD_vs_HC
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 6.08934687859775, 'gamma': 0.001537936011030912, 'kernel': 'rbf'}
# Final best score: 0.871875
# --------------- Best Params ------------------
# {'C': 6.08934687859775, 'gamma': 0.001537936011030912, 'kernel': 'rbf'}
# 0.871875
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 11.527507630986618, 'gamma': 0.0005800908425853984, 'kernel': 'rbf'}
# Final best score: 0.875
# --------------- Best Params ------------------
# {'C': 11.527507630986618, 'gamma': 0.0005800908425853984, 'kernel': 'rbf'}
# 0.875
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 24.708652641255302, 'gamma': 3.4535523544211816e-05, 'kernel': 'rbf'}
# Final best score: 0.8729166666666667
# --------------- Best Params ------------------
# {'C': 24.708652641255302, 'gamma': 3.4535523544211816e-05, 'kernel': 'rbf'}
# 0.8729166666666667
# ['C001R_AJZP_MOTOR_LECTURA.wav', 'C002_ARR_MOTOR_LECTURA.wav', 'C003_EMAO_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C019_AEG_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C034_ADV_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'C051_RAH_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P012_CAMM_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P021_LAHV_MOTOR_LECTURA.wav', 'P023_JJEV_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P025_ED_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P036_AVN_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C026_JEPM_MOTOR_LECTURA.wav', 'C032_LFMG_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P006_FAGP_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P031_AJAV_MOTOR_LECTURA.wav', 'P040_PEEG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.0001
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.5838252526883998, 'gamma': 6.984353243887705e-05, 'kernel': 'rbf'}
# Final best score: 0.8114583333333334
# --------------- Best Params ------------------
# {'C': 1.5838252526883998, 'gamma': 6.984353243887705e-05, 'kernel': 'rbf'}
# 0.8114583333333334
# ['C003_EMAO_MOTOR_LECTURA.wav', 'C004_MLQ_MOTOR_LECTURA.wav', 'C005_ABV_MOTOR_LECTURA.wav', 'C007_RSL_MOTOR_LECTURA.wav', 'C010_MVQG_MOTOR_LECTURA.wav', 'C011_JOMG_MOTOR_LECTURA.wav', 'C012_CTRE_MOTOR_LECTURA.wav', 'C014_MEMT_MOTOR_LECTURA.wav', 'C015_HJOL_MOTOR_LECTURA.wav', 'C017_JMLC_MOTOR_LECTURA.wav', 'C018_FMDV_MOTOR_LECTURA.wav', 'C020_JEG_MOTOR_LECTURA.wav', 'C023_LGMV_MOTOR_LECTURA.wav', 'C024_JAVB_MOTOR_LECTURA.wav', 'C025_IGHL_MOTOR_LECTURA.wav', 'C029_PSGL_MOTOR_LECTURA.wav', 'C030_LMLR_MOTOR_LECTURA.wav', 'C031_RALR_MOTOR_LECTURA.wav', 'C040_NELC_MOTOR_LECTURA.wav', 'C042_MHL_MOTOR_LECTURA.wav', 'C045_LARE_MOTOR_LECTURA.wav', 'C046_GGC_MOTOR_LECTURA.wav', 'C048_JLGC_MOTOR_LECTURA.wav', 'C049_MLLR_MOTOR_LECTURA.wav', 'P001_RRE_MOTOR_LECTURA.wav', 'P002_HJTC_MOTOR_LECTURA.wav', 'P003_MBCB_MOTOR_LECTURA.wav', 'P004_GGN_MOTOR_LECTURA.wav', 'P007_RAGP_MOTOR_LECTURA.wav', 'P010_EEPC_MOTOR_LECTURA.wav', 'P011_CAAA_MOTOR_LECTURA.wav', 'P013_JIRB_MOTOR_LECTURA.wav', 'P014_ACE_MOTOR_LECTURA.wav', 'P015_FAOH_MOTOR_LECTURA.wav', 'P016_LFLS_MOTOR_LECTURA.wav', 'P017_RAL_MOTOR_LECTURA.wav', 'P018_MMCM_MOTOR_LECTURA.wav', 'P019_EAS_MOTOR_LECTURA.wav', 'P024_EAAL_MOTOR_LECTURA.wav', 'P028_MCC_MOTOR_LECTURA.wav', 'P030_MRGT_MOTOR_LECTURA.wav', 'P032_AFHG_MOTOR_LECTURA.wav', 'P033_JLPJ_MOTOR_LECTURA.wav', 'P034_JLPG_MOTOR_LECTURA.wav', 'P037_CARS_MOTOR_LECTURA.wav', 'P045_JODG_MOTOR_LECTURA.wav', 'P046_GVZG_MOTOR_LECTURA.wav', 'P050_MEQG_MOTOR_LECTURA.wav', 'C006_JJHN_MOTOR_LECTURA.wav', 'C013_JIHL_MOTOR_LECTURA.wav', 'C016_EALE_MOTOR_LECTURA.wav', 'C021_GDGR_MOTOR_LECTURA.wav', 'C033R_JJEE_MOTOR_LECTURA.wav', 'C035_JRPA_MOTOR_LECTURA.wav', 'C047_ISV_MOTOR_LECTURA.wav', 'C050_BOLR_MOTOR_LECTURA.wav', 'P020_LARR_MOTOR_LECTURA.wav', 'P026_JFCC_MOTOR_LECTURA.wav', 'P029_JFMG_MOTOR_LECTURA.wav', 'P035_FGM_MOTOR_LECTURA.wav', 'P042_GEGC_MOTOR_LECTURA.wav', 'P044_CHBB_MOTOR_LECTURA.wav', 'P049_GMBM_MOTOR_LECTURA.wav', 'P051_LDTR_MOTOR_LECTURA.wav']
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 1e-05
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 73.1452805760152, 'gamma': 1.214086976880855e-05, 'kernel': 'rbf'}
# Final best score: 0.828125
# --------------- Best Params ------------------
# {'C': 73.1452805760152, 'gamma': 1.214086976880855e-05, 'kernel': 'rbf'}
# 0.828125
# [6.08934687859775, 11.527507630986618, 24.708652641255302, 1.5838252526883998, 73.1452805760152] [0.001537936011030912, 0.0005800908425853984, 3.4535523544211816e-05, 6.984353243887705e-05, 1.214086976880855e-05]
# 11.527507630986618 6.984353243887705e-05
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.938
# Sensitivity: 1.000
# Specificity: 0.875
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.625
# Sensitivity: 0.750
# Specificity: 0.500
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.625
# Specificity: 0.875
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.875
# Sensitivity: 0.750
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.800
# Sensitivity: 0.625
# Specificity: 1.000
# 0 0 0.5081660899653979
# 0 1 0.9296770472895041
# 1 0 0.8925913110342176
# 1 1 0.5686966551326413

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Reading experiments for early fusion: {fold_name}")

    results_df = pd.read_csv(f"results_motor_lectura/{fold_name}/earlyfusion_results.csv")
    
    results_test_predictions_df = pd.read_csv(f"results_motor_lectura/{fold_name}/earlyfusion_test_predictions.csv")

    for metric in ['accuracy', 'sensitivity', 'specificity', 'f1']:
        mean_val = results_df[metric].mean()
        std_val = results_df[metric].std()
        print(f"{metric.capitalize()}: {100*mean_val:.1f} ± {100*std_val:.1f}")        
    
    print()
# Out:
# Reading experiments for early fusion: CTR_DCL_vs_Park_DCL
# Accuracy: 79.0 ± 15.9
# Sensitivity: 76.7 ± 22.4
# Specificity: 83.3 ± 23.6
# F1: 77.9 ± 16.7
#
# Reading experiments for early fusion: CTR_noDCL_vs_Park_noDCL
# Accuracy: 59.3 ± 15.0
# Sensitivity: 71.0 ± 10.2
# Specificity: 45.0 ± 32.0
# F1: 64.8 ± 8.7
#
# Reading experiments for early fusion: Park_noDCL_vs_Park_DCL
# Accuracy: 65.0 ± 10.5
# Sensitivity: 40.0 ± 27.9
# Specificity: 84.0 ± 16.7
# F1: 42.8 ± 25.8
#
# Reading experiments for early fusion: PD_vs_HC
# Accuracy: 79.8 ± 12.0
# Sensitivity: 75.0 ± 15.3
# Specificity: 85.0 ± 20.5
# F1: 79.0 ± 11.0

# %% [markdown]
# ## Late fusion

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Running experiments for: {fold_name}")

    scores_artic_df = pd.read_csv(f"results_motor_lectura/{fold_name}/articulation_scores.csv")
    scores_phon_df = pd.read_csv(f"results_motor_lectura/{fold_name}/phonological_scores.csv")
    scores_pros_df = pd.read_csv(f"results_motor_lectura/{fold_name}/prosody_scores.csv")
        
    # Select and rename score columns while keeping id, outer_fold, and set_type
    artic_scores = scores_artic_df[['id', 'outer_fold', 'set_type', 'score']].rename(columns={'score': 'artic_score'})
    phon_scores = scores_phon_df[['id', 'outer_fold', 'set_type', 'score']].rename(columns={'score': 'phon_score'})
    pros_scores = scores_pros_df[['id', 'outer_fold', 'set_type', 'score']].rename(columns={'score': 'pros_score'})
        
    # Merge the dataframes
    merged_scores_df = artic_scores.merge(
        phon_scores, 
        on=['id', 'outer_fold', 'set_type']
    ).merge(
        pros_scores,
        on=['id', 'outer_fold', 'set_type']
    )

    results, scores_predictions = run_late_fusion(fold_data, merged_scores_df, type='_MOTOR_LECTURA.wav')
    results_df = pd.DataFrame(results)
    scores_predictions_df = pd.DataFrame(scores_predictions)

    # Save results
    results_df.to_csv(f"results_motor_lectura/{fold_name}/latefusion_results.csv", index=False)
    scores_predictions_df.to_csv(f"results_motor_lectura/{fold_name}/latefusion_scores.csv", index=False)
    merged_scores_df.to_csv(f"results_motor_lectura/{fold_name}/latefusion_scores.csv", index=False)

    all_y_true = [x['y_true'] for x in scores_predictions]
    all_y_proba = [x['y_proba'] for x in scores_predictions]
    all_y_pred = [x['y_pred'] for x in scores_predictions]

    os.makedirs(f"results_motor_lectura/{fold_name}/plots/", exist_ok=True)

    plot_ROC_curve(all_y_true, all_y_proba, f'results_motor_lectura/{fold_name}/plots/roc_curve_late_fusion.png')
    plot_confusion_matrix(all_y_true, all_y_pred, f'results_motor_lectura/{fold_name}/plots/confusion_matrix_late_fusion.png')
    plot_probability_density(all_y_true, all_y_proba, f'results_motor_lectura/{fold_name}/plots/probability_density_late_fusion.png')
# Out:
# Running experiments for: CTR_DCL_vs_Park_DCL
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.9129425537759532, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.9129425537759532, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 1.0
# Final SVM Params - C: 0.4692680899768591, gamma: 0.03010121430917521
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 1.000
# Specificity: 0.500
#
# Fold 2 Results:
# Train set size: 25
# Test set size: 7
# Accuracy: 0.714
# Sensitivity: 0.500
# Specificity: 1.000
#
# Fold 3 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 1.000
# Specificity: 0.667
#
# Fold 4 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 0.833
# Sensitivity: 0.667
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 26
# Test set size: 6
# Accuracy: 1.000
# Sensitivity: 1.000
# Specificity: 1.000
# 0 0 0.5283429450211456
# 0 1 0.91638985005767
# 1 0 0.91638985005767
# 1 1 0.5283429450211456
# Running experiments for: CTR_noDCL_vs_Park_noDCL
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.09129425537759533, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.9129425537759532, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.9129425537759532, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.3010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.3010121430917521, 'kernel': 'rbf'}
# 1.0
# Final SVM Params - C: 0.13167456935454494, gamma: 0.09129425537759533
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.600
# Specificity: 0.800
#
# Fold 2 Results:
# Train set size: 37
# Test set size: 10
# Accuracy: 0.700
# Sensitivity: 0.600
# Specificity: 0.800
#
# Fold 3 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.778
# Sensitivity: 0.750
# Specificity: 0.800
#
# Fold 4 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.667
# Sensitivity: 0.800
# Specificity: 0.500
#
# Fold 5 Results:
# Train set size: 38
# Test set size: 9
# Accuracy: 0.556
# Sensitivity: 0.800
# Specificity: 0.250
# 0 0 0.6350480584390619
# 0 1 0.8379969242599
# 1 0 0.8707535563244906
# 1 1 0.5967550941945405
# Running experiments for: Park_noDCL_vs_Park_DCL
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 0.96875
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 0.96875
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.13167456935454494, 'gamma': 0.9129425537759532, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.13167456935454494, 'gamma': 0.9129425537759532, 'kernel': 'rbf'}
# 1.0
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# Final best score: 1.0
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.03010121430917521, 'kernel': 'rbf'}
# 1.0
# Final SVM Params - C: 0.4692680899768591, gamma: 0.03010121430917521
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 1.000
# Specificity: 0.600
#
# Fold 2 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.625
# Sensitivity: 0.333
# Specificity: 0.800
#
# Fold 3 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 1.000
# Specificity: 0.600
#
# Fold 4 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.750
# Sensitivity: 0.333
# Specificity: 1.000
#
# Fold 5 Results:
# Train set size: 32
# Test set size: 8
# Accuracy: 0.500
# Sensitivity: 0.250
# Specificity: 0.750
# 0 0 0.5686966551326413
# 0 1 0.8925913110342176
# 1 0 0.7782006920415225
# 1 1 0.692156862745098
# Running experiments for: PD_vs_HC
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 10
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 6.08934687859775, 'gamma': 0.01537936011030912, 'kernel': 'rbf'}
# Final best score: 0.9677083333333334
# --------------- Best Params ------------------
# {'C': 6.08934687859775, 'gamma': 0.01537936011030912, 'kernel': 'rbf'}
# 0.9677083333333334
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.4692680899768591, 'gamma': 0.3010121430917521, 'kernel': 'rbf'}
# Final best score: 0.984375
# --------------- Best Params ------------------
# {'C': 0.4692680899768591, 'gamma': 0.3010121430917521, 'kernel': 'rbf'}
# 0.984375
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 100
# Initial best gamma from GridSearch: 0.01
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 14.388795539029894, 'gamma': 0.00029205021432094686, 'kernel': 'rbf'}
# Final best score: 0.9677083333333334
# --------------- Best Params ------------------
# {'C': 14.388795539029894, 'gamma': 0.00029205021432094686, 'kernel': 'rbf'}
# 0.9677083333333334
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 0.1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 0.07396788387772671, 'gamma': 0.05578141939084274, 'kernel': 'rbf'}
# Final best score: 0.984375
# --------------- Best Params ------------------
# {'C': 0.07396788387772671, 'gamma': 0.05578141939084274, 'kernel': 'rbf'}
# 0.984375
# Fitting 4 folds for each of 72 candidates, totalling 288 fits
# Initial best C from GridSearch: 1
# Initial best gamma from GridSearch: 0.1
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# Final best params from RandomizedSearch:
# {'C': 1.2270959073870447, 'gamma': 0.1305662908787999, 'kernel': 'rbf'}
# Final best score: 0.96875
# --------------- Best Params ------------------
# {'C': 1.2270959073870447, 'gamma': 0.1305662908787999, 'kernel': 'rbf'}
# 0.96875
# Final SVM Params - C: 1.2270959073870447, gamma: 0.05578141939084274
# -----------------------------------------
#
#
# Fold 1 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.938
# Sensitivity: 1.000
# Specificity: 0.875
#
# Fold 2 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.812
# Sensitivity: 0.750
# Specificity: 0.875
#
# Fold 3 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.750
# Sensitivity: 0.750
# Specificity: 0.750
#
# Fold 4 Results:
# Train set size: 63
# Test set size: 16
# Accuracy: 0.812
# Sensitivity: 0.750
# Specificity: 0.875
#
# Fold 5 Results:
# Train set size: 64
# Test set size: 15
# Accuracy: 0.800
# Sensitivity: 0.875
# Specificity: 0.714
# 0 0 0.5232987312572088
# 0 1 0.9208189158016147
# 1 0 0.9222952710495963
# 1 1 0.5207766243752403

# %%
for fold_name, fold_data in folds_data.items():
    print(f"Lectura experiments for late fusion: {fold_name}")

    results_df = pd.read_csv(f"results_motor_lectura/{fold_name}/latefusion_results.csv")

    for metric in ['accuracy', 'sensitivity', 'specificity', 'f1']:
        mean_val = results_df[metric].mean()
        std_val = results_df[metric].std()
        print(f"{metric.capitalize()}: {100*mean_val:.1f} ± {100*std_val:.1f}")        
    
    print()
# Out:
# Lectura experiments for late fusion: CTR_DCL_vs_Park_DCL
# Accuracy: 81.9 ± 11.7
# Sensitivity: 83.3 ± 23.6
# Specificity: 83.3 ± 23.6
# F1: 81.5 ± 12.5
#
# Lectura experiments for late fusion: CTR_noDCL_vs_Park_noDCL
# Accuracy: 68.0 ± 8.1
# Sensitivity: 71.0 ± 10.2
# Specificity: 63.0 ± 24.9
# F1: 69.5 ± 4.0
#
# Lectura experiments for late fusion: Park_noDCL_vs_Park_DCL
# Accuracy: 67.5 ± 11.2
# Sensitivity: 58.3 ± 38.2
# Specificity: 75.0 ± 16.6
# F1: 54.7 ± 19.5
#
# Lectura experiments for late fusion: PD_vs_HC
# Accuracy: 82.2 ± 6.9
# Sensitivity: 82.5 ± 11.2
# Specificity: 81.8 ± 7.9
# F1: 82.3 ± 7.1
